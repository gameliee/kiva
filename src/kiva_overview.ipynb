# %% [markdown]
# # Fetch data from kiva.org
#
# Take advantages of the kiva's public API

# %%
# as always, install some packages
# %pip install -q gql[all] pandas country-converter plotly

# %%
from pprint import pprint
import pandas as pd
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport

transport = RequestsHTTPTransport(url="https://api.kivaws.org/graphql")
client = Client(transport=transport, fetch_schema_from_transport=True)

# %% [markdown]
# ## Overall Stats

# %% [markdown]
# ### Countries

# %%
query = gql(
"""
{
  general {
    kivaStats {
      amountFunded
      numBorrowers,
      numCountries,
      numLenders,
      repaymentRate,
      sectors {
        name
      }
    }
  }
}
""")
result = client.execute(query)

pprint(result)
# Out:
# {'general': {'kivaStats': {'amountFunded': 1935198470,
#                            'numBorrowers': 4752764,
#                            'numCountries': 80,
#                            'numLenders': 2181437,
#                            'repaymentRate': 96.39128928000001,
#                            'sectors': [{'name': 'Agriculture'},
#                                        {'name': 'Transportation'},
#                                        {'name': 'Services'},
#                                        {'name': 'Clothing'},
#                                        {'name': 'Health'},
#                                        {'name': 'Retail'},
#                                        {'name': 'Manufacturing'},
#                                        {'name': 'Arts'},
#                                        {'name': 'Housing'},
#                                        {'name': 'Food'},
#                                        {'name': 'Wholesale'},
#                                        {'name': 'Construction'},
#                                        {'name': 'Education'},
#                                        {'name': 'Personal Use'},
#                                        {'name': 'Entertainment'}]}}}

# %%
query = gql(
"""
{
  lend {
    countryFacets {
      country {
        name
        isoCode
        region
        ppp
        numLoansFundraising
        fundsLentInCountry
      },
      count
    }
  }
}

"""
)
countries = client.execute(query)
countries = countries['lend']['countryFacets']
countries = pd.json_normalize(countries)
countries
# Out:
#     count        country.name country.isoCode   country.region country.ppp  \
# 0   212.0               Samoa              WS          Oceania      $5,200
# 1    87.0          Mozambique              MZ           Africa      $1,200
# 2    27.0  Dominican Republic              DO    North America      $9,700
# 3   163.0             Bolivia              BO    South America      $5,500
# 4   131.0           Guatemala              GT  Central America      $5,300
# ..    ...                 ...             ...              ...         ...
# 74   43.0             Vanuatu              VU          Oceania      $2,500
# 75    NaN            Mongolia              MN             Asia      $5,900
# 76    NaN                Guam              GU          Oceania     $28,700
# 77    NaN      Virgin Islands              VI    North America     $14,500
# 78    5.0         Puerto Rico              PR    North America     $16,300
#
#     country.numLoansFundraising  country.fundsLentInCountry
# 0                           212                  22483295.0
# 1                            87                   9177365.0
# 2                            27                  11925295.0
# 3                           164                  67485655.0
# 4                           131                  41159005.0
# ..                          ...                         ...
# 74                           43                   1245415.0
# 75                            0                  15691700.0
# 76                            0                     24300.0
# 77                            0                     17500.0
# 78                            5                   4605900.0
#
# [79 rows x 7 columns]

# %%
import plotly.express as px
import country_converter as coco

countries['country.iso3'] = coco.convert(countries['country.isoCode'], to='ISO3')

fig = px.choropleth(countries, locations='country.iso3', color='count', hover_name='country.name',
                    projection='natural earth',
                    title='Number of Projects by Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f940323f-4702-4240-a9d0-6e9895e7c535" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f940323f-4702-4240-a9d0-6e9895e7c535")) {                    Plotly.newPlot(                        "f940323f-4702-4240-a9d0-6e9895e7c535",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry.iso3=%{location}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Samoa","Mozambique","Dominican Republic","Bolivia","Guatemala","Paraguay","Nepal","Tajikistan","Uganda","Jordan","Palestine","Tanzania","Senegal","Cambodia","Thailand","Rwanda","Honduras","Peru","Vietnam","Philippines","Costa Rica","Panama","Kenya","Ecuador","Congo (DRC)","El Salvador","Kyrgyzstan","Israel","Nicaragua","Colombia","Georgia","Liberia","Sierra Leone","Burkina Faso","Turkey","Cameroon","India","Mexico","Brazil","Ghana","Indonesia","Kazakhstan","United States","Uzbekistan","Albania","Kosovo","Timor-Leste","Pakistan","Nigeria","Togo","Madagascar","Myanmar (Burma)","Malawi","Solomon Islands","Moldova","Chile","Lao PDR","Mali","Egypt","Haiti","Lesotho","Zambia","South Africa","Burundi","South Sudan","Zimbabwe","Bhutan","Canada","Tonga","Fiji","Bangladesh","Papua New Guinea","Benin","Namibia","Vanuatu","Mongolia","Guam","Virgin Islands","Puerto Rico"],"locations":["WSM","MOZ","DOM","BOL","GTM","PRY","NPL","TJK","UGA","JOR","PSE","TZA","SEN","KHM","THA","RWA","HND","PER","VNM","PHL","CRI","PAN","KEN","ECU","COD","SLV","KGZ","ISR","NIC","COL","GEO","LBR","SLE","BFA","TUR","CMR","IND","MEX","BRA","GHA","IDN","KAZ","USA","UZB","ALB","XKX","TLS","PAK","NGA","TGO","MDG","MMR","MWI","SLB","MDA","CHL","LAO","MLI","EGY","HTI","LSO","ZMB","ZAF","BDI","SSD","ZWE","BTN","CAN","TON","FJI","BGD","PNG","BEN","NAM","VUT","MNG","GUM","VIR","PRI"],"name":"","z":[212.0,87.0,27.0,163.0,131.0,176.0,null,523.0,297.0,110.0,66.0,3.0,303.0,110.0,62.0,83.0,115.0,83.0,161.0,940.0,54.0,11.0,1032.0,326.0,18.0,672.0,148.0,null,398.0,221.0,null,98.0,62.0,32.0,120.0,null,null,49.0,28.0,40.0,204.0,null,61.0,null,52.0,19.0,86.0,74.0,null,101.0,62.0,null,2.0,31.0,33.0,null,null,8.0,17.0,null,null,null,null,null,null,null,null,null,38.0,151.0,null,null,null,null,43.0,null,null,null,5.0],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22 ...

# %% [markdown]
# ### Tags

# %%
query = gql(
"""
{
  lend {
    tag {
      name
    }
  }
}
"""
)
tags = client.execute(query)
tags = tags['lend']['tag']
tags = [i['name'] for i in tags]
print(len(tags))
pprint(tags)
# Out:
# 76
# ['volunteer_pick',
#  'volunteer_like',
#  'user_like',
#  'user_favorite',
#  '#First Loan',
#  '#Woman-Owned Business',
#  '#Tourism',
#  '#Sustainable Ag',
#  '#Eco-friendly',
#  '#Vegan',
#  '#Animals',
#  '#Widowed',
#  '#Elderly',
#  '#Single',
#  '#Married',
#  '#Parent',
#  '#Single Parent',
#  '#Schooling',
#  '#Pre-disbursed',
#  '#Post-disbursed',
#  '#Inspiring Story',
#  '#Unique',
#  '#Interesting Photo',
#  '#Powerful Story',
#  '#Team Guys Holding Fish',
#  '#Fabrics',
#  '#Health and Sanitation',
#  '#Repeat Borrower',
#  '#Refugee',
#  '#Job Creator',
#  '#Supporting Family',
#  '#Orphan',
#  '#Low-profit FP',
#  '#Hidden Gem',
#  '#Biz Durable Asset',
#  '#Trees',
#  '#Female Education',
#  '#Technology',
#  '#Repair Renew Replace',
#  '#US immigrant',
#  'reserved_disaster_relief_covid',
#  'reserved_crisis_support_loan',
#  '#US Black-Owned Business',
#  '',
#  '#Latinx/Hispanic-Owned Business',
#  'cow',
#  'IT Cosmetics',
#  'beauty',
#  'Turo',
#  'GoDaddy',
#  '#BIPOC-owned Business',
#  '#Umpqua',
#  '#US Environmental Loan',
#  '#CommunityImpact',
#  '#FamilyImpact',
#  '#EcoFriendly',
#  '#GenderEquity',
#  '#Education',
#  '#COVID-19',
#  '#Refugees',
#  '#Agriculture',
#  '#NewBusiness',
#  '#Values',
#  '#PersonalImpact',
#  '#QualityPhotos',
#  '#TangibleProducts',
#  '#HighDetail',
#  '#StandoutBackstory',
#  '#UniqueLoanUse',
#  'MUFG',
#  'LISCChicago',
#  '#Kaiser',
#  'LGBTQ',
#  'US Refugee',
#  'Viral',
#  'Salesforce']

# %% [markdown]
# ### Sectors

# %%
query = gql(
"""
{
  lend {
    sector {
      name
    }
  }
}
"""
)
sectors = client.execute(query)
sectors = sectors['lend']['sector']
sectors = [i['name'] for i in sectors]
pprint(sectors)
# Out:
# ['Agriculture',
#  'Transportation',
#  'Services',
#  'Clothing',
#  'Health',
#  'Retail',
#  'Manufacturing',
#  'Arts',
#  'Housing',
#  'Food',
#  'Wholesale',
#  'Construction',
#  'Education',
#  'Personal Use',
#  'Entertainment']

# %% [markdown]
# ## Details data of loans

# %% [markdown]
# ### Number of projects

# %%
query = gql(
"""
{
lend {
		loans(filters: {distributionModel: both, status: all}) {
      totalCount
    }
  }
}
"""
)
loans_count = client.execute(query)
loans_count = loans_count['lend']['loans']['totalCount']
loans_count
# Out:
# 2562598

# %% [markdown]
# ### Fetch all datas
# We have to download all `2558335` projects in order to gain more insights. In the following part, I demonstrate how to fetch only 10 loans, just to show what we could do.

# %%
# Let's query a simple Loan (which is a project)
query = gql(
"""
query FetchLoans($offset: Int!, $limit: Int!)
{
  lend {
    loans(offset: $offset, limit: $limit, filters: {distributionModel: both, status: all}, sortBy: newest) {
      totalCount
      values {
        activity {
          id,
          name
        }
        anonymizationLevel
        borrowerCount
        borrowers {
          id,
          borrowedAmount,
          firstName,
          gender,
          isPrimary,
          pictured
        }
        dafEligible
        delinquent
        description
        descriptionInOriginalLanguage
        disbursalDate
        distributionModel
        endorser {
          id,
          image {
            id,
            url(presetSize: default),
          },
          inviteeCount,
          lenderPage {
            city
            state
            country {
              name
              isoCode
              region
              ppp
              numLoansFundraising
              fundsLentInCountry
            }
            loanBecause
            occupation
            otherInfo
            url
            whereabouts
          }
          loanCount
          memberSince
          name
          publicId
        }
        fundraisingDate
        gender
        geocode {
          city
          state
          country {
            name
            isoCode
            region
            ppp
            numLoansFundraising
            fundsLentInCountry
          }
          postalCode
          latitude
          longitude
        }
        hasCurrencyExchangeLossLenders
        id
        image {
          id,
          url(presetSize: default)
        }
        isMatchable
        inPfp
        loanAmount
        loanFundraisingInfo {
          fundedAmount
          isExpiringSoon
          reservedAmount
        }
        lenderRepaymentTerm
        matcherAccountId
        matcherName
        matchRatio
        matchingText
        name
        originalLanguage {
          id
          isActive
          isoCode
          name
        }
        minNoteSize
        paidAmount
        pfpMinLenders
        plannedExpirationDate
        previousLoanId
        raisedDate
        researchScore
        repaymentInterval
        sector {
          id
          name
        }
        status
        tags
        terms {
          currency
          currencyFullName
          disbursalAmount
          disbursalDate
          expectedPayments {
            amount
            dueToKivaDate
            effectiveDate
            localAmount
          }
          loanAmount
          lenderRepaymentTerm
          lossLiabilityCurrencyExchange
          lossLiabilityNonpayment
          flexibleFundraisingEnabled
        }
        use
        userProperties {
          favorited
          lentTo
          subscribed
          promoEligible
          amountInBasket
        }
        video {
          thumbnailImageId
          youtubeId
        }
        whySpecial
      }
    }
  }
}
"""
)

loans = client.execute(query, variable_values={
    "offset": 1000000,
    "limit": 10
})
pprint(loans)
# Out:
# {'lend': {'loans': {'totalCount': 2558347,
#                     'values': [{'activity': {'id': 67,
#                                              'name': 'Food Production/Sales'},
#                                 'anonymizationLevel': 'none',
#                                 'borrowerCount': 1,
#                                 'borrowers': [{'borrowedAmount': '1000.00',
#                                                'firstName': 'Ana Cecilia',
#                                                'gender': 'female',
#                                                'id': 6094078,
#                                                'isPrimary': True,
#                                                'pictured': True}],
#                                 'dafEligible': True,
#                                 'delinquent': False,
#                                 'description': 'Ana is 51 years old. She '
#                                                'studied until the 3rd grade, '
#                                                'she is married, and her '
#                                                'husband is an employee of the '
#                                                'town hall in their community. '
#                                                'She has two sons and one '
#                                                'daughter who lives with her. '
#                                                '<br />Ana has worked making '
#                                                'and selling pupusas for 30 '
#                                                'years, and can count on the '
#                                                'help of her daughter and '
#                                                'husband. Her business is in '
#                                                'her home and she works from '
#                                                'Monday to Saturday from '
#                                                '4:00p.m. until 7:00p.m.<br '
#                                                '/>Ana needs the loan to buy a '
#                                                'kitchen, utensils, and maize, '
#                                                'condiments, oil, etc., to make '
#                                                'pupusas.<br />Ana dreams of '
#                                                'renovating her house and '
#                                                'improving the quality of life '
#                                                'of her family.',
#                                 'descriptionInOriginalLanguage': 'Ana, tiene '
#                                                                  '51 años de '
#                                                                  'edad, '
#                                                                  'estudió '
#                                                                  'hasta tercer '
#                                                                  'grado en la '
#                                                                  'escuela, '
#                                                                  'está casada '
#                                                                  'y su esposo '
#                                                                  'es empleado '
#                                                                  'en la '
#                                                                  'alcaldía de '
#                                                                  'su '
#                                                                  'comunidad. '
#                                                                  'Tiene 2 '
#                                                                  'hijos y una '
#                                                                  'hija que '
#                                                                  'vive con '
#                                                                  'ella. \n'
#                                                                  '\n'
#                                                                  'Ana, se '
#                                                                  'dedica a la '
#                                                                  'elaboración '
#                                                                  'y venta de '
#                                                                  'pupusas '
#                                                                  'desde hace '
#                                                                  '30 años y '
#                                                                  'cuenta con '
#                                                                  'la ayuda su '
#                                                                  'hija y '
#                                                                  'esposo. El '
#                                                                  'negocio lo '
#                                                                  'tiene en su '
#                                                                  'casa y '
#                                                                  'trabaja de '
#                                                                  'lunes a '
#                                                                  'sábado de '
#                                                                  '4:00 pm a '
#                                                                  '7:00 pm. \n'
#                                                                  '\n'
#                                                                  'Ana, '
#                                                                  'necesita el '
#                                                                  'préstamo '
#                                                                  'para comprar '
#                                                                  'una cocina, '
#                                                                  'utensilios '
#                                                                  'de cocina y '
#                                                                  'además '
#                                                                  'comprará '
#                                                                  'maíz, '
#                                                                  'condimentos, '
#                                                                  'aceite, etc. '
#                                                                  'Para la '
#                                                                  'elaboración '
#                                                                  'y venta de '
#                                                                  'pupusas.\n'
#                                                                  '\n'
#                                                                  'Ana, sueña '
#                                                                  'con reparar '
#                                                                  'su vivienda '
#                                                                  'y mejorar la '
#                                                                  'calidad de '
#                                                                  'vida de su '
#                                                                  'familia.',
#                                 'disbursalDate': '2018-08-10T07:00:00Z',
#                                 'distributionModel': 'fieldPartner',
#                                 'endorser': None,
#                                 'fundraisingDate': '2018-08-16T20:20:06Z',
#                                 'gender': 'female',
#                                 'geocode': {'city': 'Gotera',
#                                             'country': {'fundsLentInCountry': 70180905,
#                                                         'isoCode': 'SV',
#                                                         'name': 'El Salvador',
#                                                         'numLoansFundraising': 673,
#                                                         'ppp': '$7,500',
#                                                         'region': 'Central '
#                                                                   'America'},
#                                             'latitude': 13.6927457,
#                                             'longitude': -88.1047287,
#                                             'postalCode': None,
#                                             'state': 'Morazán Department'},
#                                 'hasCurrencyExchangeLossLenders': False,
#                                 'id': 1587995,
#                                 'image': {'id': 2923996,
#                                           'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s100/ed0010b80759d2f65c7b4e1e6e06ff0c.jpg'},
#                                 'inPfp': False,
#                                 'isMatchable': False,
#                                 'lenderRepaymentTerm': 14,
#                                 'loanAmount': '1000.00',
#                                 'loanFundraisingInfo': {'fundedAmount': '1000.00',
#                                                         'isExpiringSoon': False,
#                                                         'reservedAmount': '0.00'},
#                                 'matchRatio': None,
#                                 'matcherAccountId': None,
#                                 'matcherName': None,
#                                 'matchingText': '',
#                                 'minNoteSize': '25.00',
#                                 'name': 'Ana Cecilia',
#                                 'originalLanguage': {'id': 2,
#                                                      'isActive': True,
#                                                      'isoCode': 'ES',
#                                                      'name': 'Spanish'},
#                                 'paidAmount': '0.00',
#                                 'pfpMinLenders': None,
#                                 'plannedExpirationDate': '2018-09-15T20:20:06Z',
#                                 'previousLoanId': None,
#                                 'raisedDate': '2018-09-12T21:14:03Z',
#                                 'repaymentInterval': 'monthly',
#                                 'researchScore': 4.5,
#                                 'sector': {'id': 12, 'name': 'Food'},
#                                 'status': 'funded',
#                                 'tags': ['user_favorite',
#                                          '#Woman-Owned Business',
#                                          '#Elderly',
#                                          '#Biz Durable Asset'],
#                                 'terms': {'currency': 'USD',
#                                           'currencyFullName': 'United States '
#                                                               'Dollars',
#                                           'disbursalAmount': '1000.00',
#                                           'disbursalDate': '2018-08-10T07:00:00Z',
#                                           'expectedPayments': [],
#                                           'flexibleFundraisingEnabled': False,
#                                           'lenderRepaymentTerm': 14,
#                                           'loanAmount': '1000.00',
#                                           'lossLiabilityCurrencyExchange': 'shared',
#                                           'lossLiabilityNonpayment': 'lender'},
#                                 'use': 'to buy a kitchen, utensils, and maize, '
#                                        'condiments, oil, etc., to make pupusas '
#                                        '(thick corn stuffed tortillas).',
#                                 'userProperties': {'amountInBasket': None,
#                                                    'favorited': None,
#                                                    'lentTo': None,
#                                                    'promoEligible': False,
#                                                    'subscribed': None},
#                                 'video': None,
#                                 'whySpecial': 'It enables vulnerable women to '
#                                               'start and grow their own '
#                                               'business.'},
#                                {'activity': {'id': 32, 'name': 'Tailoring'},
#                                 'anonymizationLevel': 'none',
#                                 'borrowerCount': 1,
#                                 'borrowers': [{'borrowedAmount': '700000.00',
#                                                'firstName': 'Richard',
#                                                'gender': 'male',
#                                                'id': 6093718,
#                                                'isPrimary': True,
#                                                'pictured': True}],
#                                 'dafEligible': True,
#                                 'delinquent': False,
#                                 'description': 'Richard is 25 years old and '
#                                                'single. Six years ago, he '
#                                                'decided to open a sewing '
#                                                'workshop to help him support '
#                                                'his needs and earn income. He '
#                                                'usually opens his workshop at '
#                                                '8 in the morning and closes at '
#                                                '6 in the evening. He earns a '
#                                                'good profit.<br /><br />This '
#                                                "will be Richard's second loan "
#                                                'request from Tujijenge '
#                                                'Tanzania. He used his previous '
#                                                'loan to add more stock of '
#                                                'sewing materials. He earned a '
#                                                'profit that was used to pay '
#                                                'rent for his workshop and loan '
#                                                'repayment, and repaid the loan '
#                                                'successfully. He is applying '
#                                                'for this loan to add more '
#                                                'stock of sewing materials such '
#                                                'as needles, thread, measuring '
#                                                'tapes, fashionable fabrics and '
#                                                'textiles. His dream is to grow '
#                                                'his business.<br /><br '
#                                                '/>Richard will be responsible '
#                                                'for paying back the loan '
#                                                'successfully.',
#                                 'descriptionInOriginalLanguage': 'Richard is '
#                                                                  '25 years old '
#                                                                  'and single. '
#                                                                  'Six years '
#                                                                  'ago, he '
#                                                                  'decided to '
#                                                                  'open a '
#                                                                  'sewing '
#                                                                  'workshop to '
#                                                                  'help him '
#                                                                  'support his '
#                                                                  'needs and '
#                                                                  'earn income. '
#                                                                  'He usually '
#                                                                  'opens his '
#                                                                  'workshop at '
#                                                                  '8 in the '
#                                                                  'morning and '
#                                                                  'closes at 6 '
#                                                                  'in the '
#                                                                  'evening. He '
#                                                                  'earns a good '
#                                                                  'profit.<br '
#                                                                  '/><br />This '
#                                                                  'will be '
#                                                                  "Richard's "
#                                                                  'second loan '
#                                                                  'request from '
#                                                                  'Tujijenge '
#                                                                  'Tanzania. He '
#                                                                  'used his '
#                                                                  'previous '
#                                                                  'loan to add '
#                                                                  'more stock '
#                                                                  'of sewing '
#                                                                  'materials. '
#                                                                  'He earned a '
#                                                                  'profit that '
#                                                                  'was used to '
#                                                                  'pay rent for '
#                                                                  'his workshop '
#                                                                  'and loan '
#                                                                  'repayment, '
#                                                                  'and repaid '
#                                                                  'the loan '
#                                                                  'successfully. '
#                                                                  'He is '
#                                                                  'applying for '
#                                                                  'this loan to '
#                                                                  'add more '
#                                                                  'stock of '
#                                                                  'sewing '
#                                                                  'materials '
#                                                                  'such as '
#                                                                  'needles, '
#                                                                  'thread, '
#                                                                  'measuring '
#                                                                  'tapes, '
#                                                                  'fashionable '
#                                                                  'fabrics and '
#                                                                  'textiles. '
#                                                                  'His dream is '
#                                                                  'to grow his '
#                                                                  'business.<br '
#                                                                  '/><br '
#                                                                  '/>Richard '
#                                                                  'will be '
#                                                                  'responsible '
#                                                                  'for paying '
#                                                                  'back the '
#                                                                  'loan '
#                                                                  'successfully.',
#                                 'disbursalDate': '2018-08-14T07:00:00Z',
#                                 'distributionModel': 'fieldPartner',
#                                 'endorser': None,
#                                 'fundraisingDate': '2018-08-16T20:20:02Z',
#                                 'gender': 'male',
#                                 'geocode': {'city': 'Dar es Salaam',
#                                             'country': {'fundsLentInCountry': 25932975,
#                                                         'isoCode': 'TZ',
#                                                         'name': 'Tanzania',
#                                                         'numLoansFundraising': 3,
#                                                         'ppp': '$1,900',
#                                                         'region': 'Africa'},
#                                             'latitude': -6.8,
#                                             'longitude': 39.2833333,
#                                             'postalCode': None,
#                                             'state': 'Dar es Salaam'},
#                                 'hasCurrencyExchangeLossLenders': False,
#                                 'id': 1587777,
#                                 'image': {'id': 2923687,
#                                           'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s100/717bbf86558d9360b9fc02e962bf6848.jpg'},
#                                 'inPfp': False,
#                                 'isMatchable': False,
#                                 'lenderRepaymentTerm': 5,
#                                 'loanAmount': '325.00',
#                                 'loanFundraisingInfo': {'fundedAmount': '325.00',
#                                                         'isExpiringSoon': False,
#                                                         'reservedAmount': '0.00'},
#                                 'matchRatio': None,
#                                 'matcherAccountId': None,
#                                 'matcherName': None,
#                                 'matchingText': '',
#                                 'minNoteSize': '25.00',
#                                 'name': 'Richard',
#                                 'originalLanguage': {'id': 1,
#                                                      'isActive': True,
#                                                      'isoCode': 'EN',
#                                                      'name': 'English'},
#                                 'paidAmount': '0.00',
#                                 'pfpMinLenders': None,
#                                 'plannedExpirationDate': '2018-09-15T20:20:02Z',
#                                 'previousLoanId': None,
#                                 'raisedDate': '2018-08-17T10:37:38Z',
#                                 'repaymentInterval': 'monthly',
#                                 'researchScore': 0.5,
#                                 'sector': {'id': 4, 'name': 'Services'},
#                                 'status': 'funded',
#                                 'tags': [],
#                                 'terms': {'currency': 'TZS',
#                                           'currencyFullName': 'Tanzania '
#                                                               'Shillings',
#                                           'disbursalAmount': '700000.00',
#                                           'disbursalDate': '2018-08-14T07:00:00Z',
#                                           'expectedPayments': [],
#                                           'flexibleFundraisingEnabled': False,
#                                           'lenderRepaymentTerm': 5,
#                                           'loanAmount': '325.00',
#                                           'lossLiabilityCurrencyExchange': 'shared',
#                                           'lossLiabilityNonpayment': 'lender'},
#                                 'use': 'to add more stock of sewing materials '
#                                        'such as needles, thread, measuring '
#                                        'tapes, fashionable fabrics and '
#                                        'textiles.',
#                                 'userProperties': {'amountInBasket': None,
#                                                    'favorited': None,
#                                                    'lentTo': None,
#                                                    'promoEligible': False,
#                                                    'subscribed': None},
#                                 'video': None,
#                                 'whySpecial': 'It provides loans to borrowers '
#                                               'in very deep rural areas via '
#                                               'mobile money innovation.'},
#                                {'activity': {'id': 31, 'name': 'Farming'},
#                                 'anonymizationLevel': 'none',
#                                 'borrowerCount': 1,
#                                 'borrowers': [{'borrowedAmount': '674.97',
#                                                'firstName': 'Elizabeth ',
#                                                'gender': 'female',
#                                                'id': 6094070,
#                                                'isPrimary': True,
#                                                'pictured': True}],
#                                 'dafEligible': False,
#                                 'delinquent': False,
#                                 'description': 'Elizabeth has been working her '
#                                                'rice farm for 5 years.  She is '
#                                                'married with 4 children.  '
#                                                'Elizabeth is asking for a loan '
#                                                'to buy rice seeds, fertilizer, '
#                                                'herbicide and pesticide. Her '
#                                                'farm is in Weta, an area of '
#                                                'the Volta Region that has many '
#                                                'rice farms.\n'
#                                                '\n'
#                                                'Elizabeth wants to have a more '
#                                                'regular income instead of only '
#                                                'relying on the harvest.  With '
#                                                'the profit she makes after '
#                                                'using the inputs, Elizabeth '
#                                                'plans on starting a small '
#                                                'trading business to help her '
#                                                'family financially throughout '
#                                                'the year.\n'
#                                                '\n'
#                                                'Elizabeth is a good woman, '
#                                                'please lend to her today!',
#                                 'descriptionInOriginalLanguage': 'Elizabeth '
#                                                                  'has been '
#                                                                  'working her '
#                                                                  'rice farm '
#                                                                  'for 5 '
#                                                                  'years.  She '
#                                                                  'is married '
#                                                                  'with 4 '
#                                                                  'children.  '
#                                                                  'Elizabeth is '
#                                                                  'asking for a '
#                                                                  'loan to buy '
#                                                                  'rice seeds, '
#                                                                  'fertilizer, '
#                                                                  'herbicide '
#                                                                  'and '
#                                                                  'pesticide. '
#                                                                  'Her farm is '
#                                                                  'in Weta, an '
#                                                                  'area of the '
#                                                                  'Volta Region '
#                                                                  'that has '
#                                                                  'many rice '
#                                                                  'farms.\n'
#                                                                  '\n'
#                                                                  'Elizabeth '
#                                                                  'wants to '
#                                                                  'have a more '
#                                                                  'regular '
#                                                                  'income '
#                                                                  'instead of '
#                                                                  'only relying '
#                                                                  'on the '
#                                                                  'harvest.  '
#                                                                  'With the '
#                                                                  'profit she '
#                                                                  'makes after '
#                                                                  'using the '
#                                                                  'inputs, '
#                                                                  'Elizabeth '
#                                                                  'plans on '
#                                                                  'starting a '
#                                                                  'small '
#                                                                  'trading '
#                                                                  'business to '
#                                                                  'help her '
#                                                                  'family '
#                                                                  'financially '
#                                                                  'throughout '
#                                                                  'the year.\n'
#                                                                  '\n'
#                                                                  'Elizabeth is '
#                                                                  'a good '
#                                                                  'woman, '
#                                                                  'please lend '
#                                                                  'to her '
#                                                                  'today!',
#                                 'disbursalDate': '2018-07-17T07:00:00Z',
#                                 'distributionModel': 'fieldPartner',
#                                 'endorser': None,
#                                 'fundraisingDate': '2018-08-16T20:00:07Z',
#                                 'gender': 'female',
#                                 'geocode': {'city': 'Weta',
#                                             'country': {'fundsLentInCountry': 23641300,
#                                                         'isoCode': 'GH',
#                                                         'name': 'Ghana',
#                                                         'numLoansFundraising': 40,
#                                                         'ppp': '$3,500',
#                                                         'region': 'Africa'},
#                                             'latitude': 6.0802847,
#                                             'longitude': 0.9748978,
#                                             'postalCode': None,
#                                             'state': 'Volta Region'},
#                                 'hasCurrencyExchangeLossLenders': False,
#                                 'id': 1587990,
#                                 'image': {'id': 2923987,
#                                           'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s100/bdd461074e108db86aa4d1db71bf5daa.jpg'},
#                                 'inPfp': False,
#                                 'isMatchable': False,
#                                 'lenderRepaymentTerm': 8,
#                                 'loanAmount': '150.00',
#                                 'loanFundraisingInfo': {'fundedAmount': '150.00',
#                                                         'isExpiringSoon': False,
#                                                         'reservedAmount': '0.00'},
#                                 'matchRatio': None,
#                                 'matcherAccountId': None,
#                                 'matcherName': None,
#                                 'matchingText': '',
#                                 'minNoteSize': '25.00',
#                                 'name': 'Elizabeth',
#                                 'originalLanguage': {'id': 1,
#                                                      'isActive': True,
#                                                      'isoCode': 'EN',
#                                                      'name': 'English'},
#                                 'paidAmount': '0.00',
#                                 'pfpMinLenders': None,
#                                 'plannedExpirationDate': '2018-09-15T20:00:07Z',
#                                 'previousLoanId': None,
#                                 'raisedDate': '2018-08-16T21:19:23Z',
#                                 'repaymentInterval': 'at_end',
#                                 'researchScore': 8,
#                                 'sector': {'id': 1, 'name': 'Agriculture'},
#                                 'status': 'funded',
#                                 'tags': [],
#                                 'terms': {'currency': 'GHS',
#                                           'currencyFullName': 'Ghana Cedis',
#                                           'disbursalAmount': '674.97',
#                                           'disbursalDate': '2018-07-17T07:00:00Z',
#                                           'expectedPayments': [],
#                                           'flexibleFundraisingEnabled': False,
#                                           'lenderRepaymentTerm': 8,
#                                           'loanAmount': '150.00',
#                                           'lossLiabilityCurrencyExchange': 'shared',
#                                           'lossLiabilityNonpayment': 'lender'},
#                                 'use': 'to buy rice seeds, fertilizer, '
#                                        'herbicide and pesticide for rice '
#                                        'farming.',
#                                 'userProperties': {'amountInBasket': None,
#                                                    'favorited': None,
#                                                    'lentTo': None,
#                                                    'promoEligible': False,
#                                                    'subscribed': None},
#                                 'video': None,
#                                 'whySpecial': 'It supports rural farmers who '
#                                               'traditionally have limited '
#                                               'access to funding.'},
#                                {'activity': {'id': 31, 'name': 'Farming'},
#                                 'anonymizationLevel': 'none',
#                                 'borrowerCount': 1,
#                                 'borrowers': [{'borrowedAmount': '22796.20',
#                                                'firstName': 'Ado',
#                                                'gender': 'male',
#                                                'id': 6094074,
#                                                'isPrimary': True,
#                                                'pictured': True}],
#                                 'dafEligible': False,
#                                 'delinquent': False,
#                                 'description': 'Ado is married and lives with '
#                                                'his family in a simple mud '
#                                                'house in a small village in '
#                                                'Kaduna state. In his '
#                                                'community, farming is the '
#                                                'primary occupation and, like '
#                                                'many hardworking smallholders, '
#                                                'he dreams of expanding his '
#                                                'farm business.\n'
#                                                '\n'
#                                                'Ado is returning to work with '
#                                                'Babban Gona this season as he '
#                                                'will get access to '
#                                                'better-yielding seeds, '
#                                                'fertilizers and other '
#                                                'essential farm inputs that '
#                                                'will boost his yield. Apart '
#                                                'from increasing Ado’s yield to '
#                                                'ensure that his family never '
#                                                'goes hungry, this loan will '
#                                                'also help him earn up to 3 '
#                                                'times in net income, compared '
#                                                'to the average Nigerian '
#                                                'farmer, from selling his '
#                                                'maize. Since he joined Babban '
#                                                'Gona in 2016, his happiest '
#                                                'memory was buying a tractor.\n'
#                                                '\n'
#                                                'With lenders’ support to grow '
#                                                'his farming business, Ado is '
#                                                'looking forward to an abundant '
#                                                'harvest. Ado plans to use the '
#                                                'profits from this season’s '
#                                                "harvest to pay his children's "
#                                                'school fees.',
#                                 'descriptionInOriginalLanguage': 'Ado is '
#                                                                  'married and '
#                                                                  'lives with '
#                                                                  'his family '
#                                                                  'in a simple '
#                                                                  'mud house in '
#                                                                  'a small '
#                                                                  'village in '
#                                                                  'Kaduna '
#                                                                  'state. In '
#                                                                  'his '
#                                                                  'community, '
#                                                                  'farming is '
#                                                                  'the primary '
#                                                                  'occupation '
#                                                                  'and, like '
#                                                                  'many '
#                                                                  'hardworking '
#                                                                  'smallholders, '
#                                                                  'he dreams of '
#                                                                  'expanding '
#                                                                  'his farm '
#                                                                  'business.\n'
#                                                                  '\n'
#                                                                  'Ado is '
#                                                                  'returning to '
#                                                                  'work with '
#                                                                  'Babban Gona '
#                                                                  'this season '
#                                                                  'as he will '
#                                                                  'get access '
#                                                                  'to '
#                                                                  'better-yielding '
#                                                                  'seeds, '
#                                                                  'fertilizers '
#                                                                  'and other '
#                                                                  'essential '
#                                                                  'farm inputs '
#                                                                  'that will '
#                                                                  'boost his '
#                                                                  'yield. Apart '
#                                                                  'from '
#                                                                  'increasing '
#                                                                  'Ado’s yield '
#                                                                  'to ensure '
#                                                                  'that his '
#                                                                  'family never '
#                                                                  'goes hungry, '
#                                                                  'this loan '
#                                                                  'will also '
#                                                                  'help him '
#                                                                  'earn up to 3 '
#                                                                  'times in net '
#                                                                  'income, '
#                                                                  'compared to '
#                                                                  'the average '
#                                                                  'Nigerian '
#                                                                  'farmer, from '
#                                                                  'selling his '
#                                                                  'maize. Since '
#                                                                  'he joined '
#                                                                  'Babban Gona '
#                                                                  'in 2016, his '
#                                                                  'happiest '
#                                                                  'memory was '
#                                                                  'buying a '
#                                                                  'tractor.\n'
#                                                                  '\n'
#                                                                  'With '
#                                                                  'lenders’ '
#                                                                  'support to '
#                                                                  'grow his '
#                                                                  'farming '
#                                                                  'business, '
#                                                                  'Ado is '
#                                                                  'looking '
#                                                                  'forward to '
#                                                                  'an abundant '
#                                                                  'harvest. Ado '
#                                                                  'plans to use '
#                                                                  'the profits '
#                                                                  'from this '
#                                                                  'season’s '
#                                                                  'harvest to '
#                                                                  'pay his '
#                                                                  "children's "
#                                                                  'school fees.',
#                                 'disbursalDate': '2018-07-15T07:00:00Z',
#                                 'distributionModel': 'fieldPartner',
#                                 'endorser': None,
#                                 'fundraisingDate': '2018-08-16T20:00:06Z',
#                                 'gender': 'male',
#                                 'geocode': {'city': 'Kaduna',
#                                             'country': {'fundsLentInCountry': 11221160,
#                                                         'isoCode': 'NG',
# ...
#                                 'loanAmount': '700.00',
#                                 'loanFundraisingInfo': {'fundedAmount': '700.00',
#                                                         'isExpiringSoon': False,
#                                                         'reservedAmount': '0.00'},
#                                 'matchRatio': None,
#                                 'matcherAccountId': None,
#                                 'matcherName': None,
#                                 'matchingText': '',
#                                 'minNoteSize': '25.00',
#                                 'name': 'Samuel De Jesús',
#                                 'originalLanguage': {'id': 2,
#                                                      'isActive': True,
#                                                      'isoCode': 'ES',
#                                                      'name': 'Spanish'},
#                                 'paidAmount': '0.00',
#                                 'pfpMinLenders': None,
#                                 'plannedExpirationDate': '2018-09-15T20:00:05Z',
#                                 'previousLoanId': None,
#                                 'raisedDate': '2018-08-21T21:40:10Z',
#                                 'repaymentInterval': 'monthly',
#                                 'researchScore': 8,
#                                 'sector': {'id': 12, 'name': 'Food'},
#                                 'status': 'funded',
#                                 'tags': ['volunteer_pick'],
#                                 'terms': {'currency': 'USD',
#                                           'currencyFullName': 'United States '
#                                                               'Dollars',
#                                           'disbursalAmount': '700.00',
#                                           'disbursalDate': '2018-07-24T07:00:00Z',
#                                           'expectedPayments': [],
#                                           'flexibleFundraisingEnabled': False,
#                                           'lenderRepaymentTerm': 14,
#                                           'loanAmount': '700.00',
#                                           'lossLiabilityCurrencyExchange': 'shared',
#                                           'lossLiabilityNonpayment': 'lender'},
#                                 'use': 'to buy fishing nets.',
#                                 'userProperties': {'amountInBasket': None,
#                                                    'favorited': None,
#                                                    'lentTo': None,
#                                                    'promoEligible': False,
#                                                    'subscribed': None},
#                                 'video': None,
#                                 'whySpecial': 'It helps rural farmers and '
#                                               'fishermen, while teaching '
#                                               'sustainable agricultural '
#                                               'practices.'},
#                                {'activity': {'id': 169,
#                                              'name': 'Fruits & Vegetables'},
#                                 'anonymizationLevel': 'none',
#                                 'borrowerCount': 1,
#                                 'borrowers': [{'borrowedAmount': '400.00',
#                                                'firstName': 'Elisita ',
#                                                'gender': 'female',
#                                                'id': 6094508,
#                                                'isPrimary': True,
#                                                'pictured': True}],
#                                 'dafEligible': True,
#                                 'delinquent': False,
#                                 'description': 'This is Elisita, a talented '
#                                                'and enterprising 40-year-old '
#                                                'woman who possesses a strong '
#                                                'desire to get ahead. She has '
#                                                'gained experience and a good '
#                                                'understanding of business from '
#                                                'running her own local '
#                                                'vegetable business for many '
#                                                'years now. Running the '
#                                                'business has made Elisita '
#                                                'become more independent '
#                                                'because she can be responsible '
#                                                "for herself and her family's "
#                                                'everyday needs. <br /><br '
#                                                '/>She would like a loan of '
#                                                '$400 USD through KIF to help '
#                                                'improve her vegetables-selling '
#                                                'business. She plans to use '
#                                                'this loan to buy more types of '
#                                                'local vegetables to resell at '
#                                                'her shop to provide better '
#                                                'income for her family. <br '
#                                                '/><br />Elisita hopes to '
#                                                'expand her business in the '
#                                                'future and wants to thank '
#                                                'lenders for the opportunity.',
#                                 'descriptionInOriginalLanguage': 'This is '
#                                                                  'Elisita, a '
#                                                                  'talented and '
#                                                                  'enterprising '
#                                                                  '40-year-old '
#                                                                  'woman who '
#                                                                  'possesses a '
#                                                                  'strong '
#                                                                  'desire to '
#                                                                  'get ahead. '
#                                                                  'She has '
#                                                                  'gained '
#                                                                  'experience '
#                                                                  'and a good '
#                                                                  'understanding '
#                                                                  'of business '
#                                                                  'from running '
#                                                                  'her own '
#                                                                  'local '
#                                                                  'vegetable '
#                                                                  'business for '
#                                                                  'many years '
#                                                                  'now. Running '
#                                                                  'the business '
#                                                                  'has made '
#                                                                  'Elisita '
#                                                                  'become more '
#                                                                  'independent '
#                                                                  'because she '
#                                                                  'can be '
#                                                                  'responsible '
#                                                                  'for herself '
#                                                                  'and her '
#                                                                  "family's "
#                                                                  'everyday '
#                                                                  'needs. <br '
#                                                                  '/><br />She '
#                                                                  'would like a '
#                                                                  'loan of $400 '
#                                                                  'USD through '
#                                                                  'KIF to help '
#                                                                  'improve her '
#                                                                  'vegetables-selling '
#                                                                  'business. '
#                                                                  'She plans to '
#                                                                  'use this '
#                                                                  'loan to buy '
#                                                                  'more types '
#                                                                  'of local '
#                                                                  'vegetables '
#                                                                  'to resell at '
#                                                                  'her shop to '
#                                                                  'provide '
#                                                                  'better '
#                                                                  'income for '
#                                                                  'her family. '
#                                                                  '<br /><br '
#                                                                  '/>Elisita '
#                                                                  'hopes to '
#                                                                  'expand her '
#                                                                  'business in '
#                                                                  'the future '
#                                                                  'and wants to '
#                                                                  'thank '
#                                                                  'lenders for '
#                                                                  'the '
#                                                                  'opportunity.',
#                                 'disbursalDate': '2018-07-30T07:00:00Z',
#                                 'distributionModel': 'fieldPartner',
#                                 'endorser': None,
#                                 'fundraisingDate': '2018-08-16T20:00:05Z',
#                                 'gender': 'female',
#                                 'geocode': {'city': 'Same',
#                                             'country': {'fundsLentInCountry': 11047845,
#                                                         'isoCode': 'TL',
#                                                         'name': 'Timor-Leste',
#                                                         'numLoansFundraising': 86,
#                                                         'ppp': '$6,800',
#                                                         'region': 'Oceania'},
#                                             'latitude': -9.0020538,
#                                             'longitude': 125.6478189,
#                                             'postalCode': None,
#                                             'state': 'Manufahi'},
#                                 'hasCurrencyExchangeLossLenders': False,
#                                 'id': 1588110,
#                                 'image': {'id': 2924129,
#                                           'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s100/6e8c2868433e9d46794e661b6b99a646.jpg'},
#                                 'inPfp': False,
#                                 'isMatchable': False,
#                                 'lenderRepaymentTerm': 15,
#                                 'loanAmount': '400.00',
#                                 'loanFundraisingInfo': {'fundedAmount': '400.00',
#                                                         'isExpiringSoon': False,
#                                                         'reservedAmount': '0.00'},
#                                 'matchRatio': None,
#                                 'matcherAccountId': None,
#                                 'matcherName': None,
#                                 'matchingText': '',
#                                 'minNoteSize': '25.00',
#                                 'name': 'Elisita',
#                                 'originalLanguage': {'id': 1,
#                                                      'isActive': True,
#                                                      'isoCode': 'EN',
#                                                      'name': 'English'},
#                                 'paidAmount': '0.00',
#                                 'pfpMinLenders': None,
#                                 'plannedExpirationDate': '2018-09-15T20:00:05Z',
#                                 'previousLoanId': None,
#                                 'raisedDate': '2018-08-19T22:52:49Z',
#                                 'repaymentInterval': 'monthly',
#                                 'researchScore': 3.5,
#                                 'sector': {'id': 12, 'name': 'Food'},
#                                 'status': 'funded',
#                                 'tags': [],
#                                 'terms': {'currency': 'USD',
#                                           'currencyFullName': 'United States '
#                                                               'Dollars',
#                                           'disbursalAmount': '400.00',
#                                           'disbursalDate': '2018-07-30T07:00:00Z',
#                                           'expectedPayments': [],
#                                           'flexibleFundraisingEnabled': False,
#                                           'lenderRepaymentTerm': 15,
#                                           'loanAmount': '400.00',
#                                           'lossLiabilityCurrencyExchange': 'none',
#                                           'lossLiabilityNonpayment': 'lender'},
#                                 'use': 'to buy more types of local vegetables '
#                                        'to resell at her shop to provide '
#                                        'better income for her family.',
#                                 'userProperties': {'amountInBasket': None,
#                                                    'favorited': None,
#                                                    'lentTo': None,
#                                                    'promoEligible': False,
#                                                    'subscribed': None},
#                                 'video': None,
#                                 'whySpecial': 'It provides entrepreneurs in '
#                                               'underserved communities with '
#                                               'the means to grow their '
#                                               'businesses.'}]}}}

# %% [markdown]
# Some columns of interested are
#
# | column name | meaning |
# |-------------|---------|
# | `loanAmount` | The amount of this loan, as shown to lenders |
# | `fundedAmount` | The amount of the loan that has been purchased by lenders |
# | `raisedDate` | When the loan became raised, e.g. fully funded. Same as funded_date in v1 |
# | `fundraisingDate` | When the loan started fundraising on Kiva. Same as posted_date in v1 |
# | `plannedExpirationDate` | When the loan will expire if it is not fully funded |
# | `disbursalDate` | The date on which the partner disbursed and/or intends to disburse the loan to the borrower |
#
# those meanings are taken from Kiva's GraphQL Schema.

# %%
df = pd.json_normalize(loans['lend']['loans']['values'])
df['raisedDate'] = pd.to_datetime(df['raisedDate'])
df['fundraisingDate'] = pd.to_datetime(df['fundraisingDate'])
df['loanFundraisingInfo.fundedAmount'] = df['loanFundraisingInfo.fundedAmount'].astype(float)
df[['loanAmount', 'loanFundraisingInfo.fundedAmount', 'raisedDate', 'fundraisingDate', 'plannedExpirationDate', 'disbursalDate', ]]
# Out:
#   loanAmount  loanFundraisingInfo.fundedAmount                raisedDate  \
# 0    1000.00                            1000.0 2018-09-12 21:14:03+00:00
# 1     325.00                             325.0 2018-08-17 10:37:38+00:00
# 2     150.00                             150.0 2018-08-16 21:19:23+00:00
# 3      75.00                              75.0 2018-08-17 00:03:42+00:00
# 4     325.00                             325.0 2018-08-18 11:53:49+00:00
# 5     175.00                             175.0 2018-08-18 12:30:15+00:00
# 6     900.00                             900.0 2018-08-21 12:10:14+00:00
# 7    3475.00                            3475.0 2018-09-15 19:58:12+00:00
# 8     700.00                             700.0 2018-08-21 21:40:10+00:00
# 9     400.00                             400.0 2018-08-19 22:52:49+00:00
#
#             fundraisingDate plannedExpirationDate         disbursalDate
# 0 2018-08-16 20:20:06+00:00  2018-09-15T20:20:06Z  2018-08-10T07:00:00Z
# 1 2018-08-16 20:20:02+00:00  2018-09-15T20:20:02Z  2018-08-14T07:00:00Z
# 2 2018-08-16 20:00:07+00:00  2018-09-15T20:00:07Z  2018-07-17T07:00:00Z
# 3 2018-08-16 20:00:06+00:00  2018-09-15T20:00:06Z  2018-07-15T07:00:00Z
# 4 2018-08-16 20:00:06+00:00  2018-09-15T20:00:06Z  2018-07-15T07:00:00Z
# 5 2018-08-16 20:00:06+00:00  2018-09-15T20:00:06Z  2018-07-15T07:00:00Z
# 6 2018-08-16 20:00:06+00:00  2018-09-15T20:00:06Z  2018-08-18T07:00:00Z
# 7 2018-08-16 20:00:06+00:00  2018-09-15T20:00:06Z  2018-08-03T07:00:00Z
# 8 2018-08-16 20:00:05+00:00  2018-09-15T20:00:05Z  2018-07-24T07:00:00Z
# 9 2018-08-16 20:00:05+00:00  2018-09-15T20:00:05Z  2018-07-30T07:00:00Z

# %%
# Calculate the amount of money collected per day
df['funding_duration'] = df['raisedDate'] - df['fundraisingDate']
df['funding_duration_days'] = df['funding_duration'].dt.total_seconds() / (24 * 60 * 60)
df['collection_speed'] = df['loanFundraisingInfo.fundedAmount'] / df['funding_duration_days']
df['collection_speed']
# Out:
# 0      36.985716
# 1     545.708955
# 2    2724.978974
# 3     443.349754
# 4     195.511861
# 5     103.697303
# 6     192.566764
# 7     115.838428
# 8     138.080616
# 9     128.207031
# Name: collection_speed, dtype: float64
